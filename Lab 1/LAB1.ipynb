# %% [markdown]
# ## 19103055 DA Lab1
# ### Khushi

# %%
# Ques 1:

isLucky<- function(numList){
    for(num in numList){
        if(num %% 7 ==0)
        return (TRUE)
    }
    return (FALSE)

}
ans1<-isLucky(c(1,2,4,7)) 
ans2<-isLucky(c(1,2,4,5))
result<-paste(as.character(ans1), as.character(ans2 ), sep=" ")
print(result)
# Out:
# [1] "TRUE FALSE"

# %%
# Ques 2:

# "Data Science" will be printed 11 Times.
# can be seeen below:

i<-1024
c<-1
while(i>0){
cat(c,"Data Science","\n")
i= as.integer(i/2)
c=c+1
}
# Out:
# 1 Data Science
# 2 Data Science
# 3 Data Science
# 4 Data Science
# 5 Data Science
# 6 Data Science
# 7 Data Science
# 8 Data Science
# 9 Data Science
# 10 Data Science
# 11 Data Science

# %%
# Ques 3:
num <- sample(1:100, 1)
message <- "Guess a Number between 1 to 100 in 5 Tries : "
# print(message)

for (i in c(1:5)) {
    x <- readline(prompt = message)
    flush.console()
    if (x < num) {
        message <- "Move to a Higher Number!! : "
    } else if (x > num) {
        message <- "Move to a Lower Number!! : "
    } else {
        print( "U guessed It correct Congrats!!")
        break
    }
}
if (i == 5) {
    if (x != num) {
        print(paste("Oops You lost! Better Luck Next Time!, Number = ",num))
    } else {
        print("U guessed It correct Congrats!!")
    }
}
# Out:
# [1] "Oops You lost! Better Luck Next Time!, Number =  70"

# %%
#Ques 4:

check_tossProbability<- function(SampleSize){
Prob<-c(0.5,0.5)
my_sample<-sample(0:1,SampleSize,replace=TRUE,prob=Prob)
h<-sum(my_sample==1)
t<-sum(my_sample==0)
print(paste("For Sample Size = ",SampleSize))
print(paste("Heads(1) = ",h,", Probability of Head = ",h/SampleSize))
print(paste("Tails(0) = ",t,", Probability of Tail = ",t/SampleSize,"\n",sep=""))
}

# %%
check_tossProbability(1000)
# Out:
# [1] "For Sample Size =  1000"
# [1] "Heads(1) =  482 , Probability of Head =  0.482"
# [1] "Tails(0) = 518, Probability of Tail = 0.518\n"

# %%
check_tossProbability(10000)
# Out:
# [1] "For Sample Size =  10000"
# [1] "Heads(1) =  5002 , Probability of Head =  0.5002"
# [1] "Tails(0) = 4998, Probability of Tail = 0.4998\n"

# %%
check_tossProbability(100000)
# As the answers are approx = 0.5 so yes the results hold for large samples too
# This is beacause Tossing of a coin is independent event 
# and whether it is tossed 1 time or 100 it wont affect the prob. of head and tail.
# Out:
# [1] "For Sample Size =  1e+05"
# [1] "Heads(1) =  49850 , Probability of Head =  0.4985"
# [1] "Tails(0) = 50150, Probability of Tail = 0.5015\n"

# %%
#Ques 5:
remove_multiples_of_three <- function(numList){
# The function takes a list of numbers and returns the list without multiples of 3.
x<- numList[numList%%3!=0]
return (x)
}

print(remove_multiples_of_three(c(1,2,3,4,30,23,21)))
# Out:
# [1]  1  2  4 23

# %%
#Ques 6 :

cereals <- structure(c(431.87, 284.33, 621.44, 95.01, 106.03, 102.45, 475.96, 297.85,
616.25, 102.93, 84.13, 117.74, 440.12, 313.61, 617.93, 109.33, 117.78, 131.14), .Dim =
c(6L, 3L), .Dimnames = list(c("United States", "India", "China", "Indonesia", "Braziiil Ole
Ole", "Russian Federation"), c("2015", "2016", "in 2017")))

cereals
# Out:
#                    2015   2016   in 2017
# United States      431.87 475.96 440.12
# India              284.33 297.85 313.61
# China              621.44 616.25 617.93
# Indonesia           95.01 102.93 109.33
# Braziiil Ole\nOle  106.03  84.13 117.78
# Russian Federation 102.45 117.74 131.14

# %%
#a.  Yes
print(is.matrix(cereals))

#b.  6X3
dim(cereals)

#c. 
# Row Names: United States, India, China, Indonesia, Braziiil Ole Ole, Russian Federation 
#Col Names : 2015, 2016, in 2017
x<-rownames(cereals)
cat("Row Names : \n")
x
length(x)==dim(cereals)[1]

y<-colnames(cereals)
cat("Column Names : \n")
y
length(y)==dim(cereals)[2]


#d. 
colnames(cereals)[3]<-"2017"
rownames(cereals)[5]<-"Brazil"
# Out:
# [1] TRUE
# [1] 6 3
# Row Names :
# [1] "United States"      "India"              "China"
# [4] "Indonesia"          "Braziiil Ole\nOle"  "Russian Federation"
# [1] TRUE
# Column Names :
# [1] "2015"    "2016"    "in 2017"
# [1] TRUE

# %%
dim=dimnames(cereals)
print(dim)
print(lengths(dim[1])==dim(cereals)[1])
print(lengths(dim[2])==dim(cereals)[2])
# Out:
# [[1]]
# [1] "United States"      "India"              "China"
# [4] "Indonesia"          "Brazil"             "Russian Federation"
#
# [[2]]
# [1] "2015" "2016" "2017"
#
# [1] TRUE
# [1] TRUE

# %%
#Ques 7: 

Name <- c('Antansia','Dima','Katherine','James','Emily','Michael','Matthew','Laura','Kevin','Jonas')
Score <- c(11.5,8.0,15.5,1.0,5.5,19.0,12.5,10.5,7.0,8.0)
Attempts <- c(3,3,NA,2,NA,NA,1,1,2,NA)
Qualify <- c('yes','no','yes','no','no','yes','yes','no','no','yes')
Gender <- c('F','F','F','M','F','M','M','F','M','M')
Age <- c(18,17,NA,NA,19,17,18,17,19,19)
df<- data.frame(Name,Score,Attempts,Qualify,Gender,Age)
df
# Out:
#    Name      Score Attempts Qualify Gender Age
# 1  Antansia  11.5   3       yes     F      18
# 2  Dima       8.0   3       no      F      17
# 3  Katherine 15.5  NA       yes     F      NA
# 4  James      1.0   2       no      M      NA
# 5  Emily      5.5  NA       no      F      19
# 6  Michael   19.0  NA       yes     M      17
# 7  Matthew   12.5   1       yes     M      18
# 8  Laura     10.5   1       no      F      17
# 9  Kevin      7.0   2       no      M      19
# 10 Jonas      8.0  NA       yes     M      19

# %%
#b.

df=df[,which(colnames(df)!='Gender')]
#df=df[,-5]
#df = subset(df, select = -c(Gender)) 
#df=df[c('Name','Score','Attempts','Qualify','Age')]
#df$Gender<-NULL
print(df)

#c.
cat("\n\n","No. of Null Values in each column: ","\n")
print(data.frame(colSums(is.na(df))))

#d.
cat("\n\n","Null Values Replaced by Means:  ","\n")
df[is.na(df[,'Age']),'Age']<-mean(df[,'Age'],na.rm=TRUE)
df[is.na(df[,'Attempts']),'Attempts']<-mean(df[,'Attempts'],na.rm=TRUE)
print(df)

#e.
cat("\n\n","Scores incremented by One:   ","\n")
df['Score']<-df['Score']+1
print(df[,'Score'])
# Out:
#         Name Score Attempts Qualify Age
# 1   Antansia  11.5        3     yes  18
# 2       Dima   8.0        3      no  17
# 3  Katherine  15.5       NA     yes  NA
# 4      James   1.0        2      no  NA
# 5      Emily   5.5       NA      no  19
# 6    Michael  19.0       NA     yes  17
# 7    Matthew  12.5        1     yes  18
# 8      Laura  10.5        1      no  17
# 9      Kevin   7.0        2      no  19
# 10     Jonas   8.0       NA     yes  19
#
#
#  No. of Null Values in each column:
#          colSums.is.na.df..
# Name                      0
# Score                     0
# Attempts                  4
# Qualify                   0
# Age                       2
#
#
#  Null Values Replaced by Means:
#         Name Score Attempts Qualify Age
# 1   Antansia  11.5        3     yes  18
# 2       Dima   8.0        3      no  17
# 3  Katherine  15.5        2     yes  18
# 4      James   1.0        2      no  18
# 5      Emily   5.5        2      no  19
# 6    Michael  19.0        2     yes  17
# 7    Matthew  12.5        1     yes  18
# 8      Laura  10.5        1      no  17
# 9      Kevin   7.0        2      no  19
# 10     Jonas   8.0        2     yes  19
#
#
#  Scores incremented by One:
#  [1] 12.5  9.0 16.5  2.0  6.5 20.0 13.5 11.5  8.0  9.0

# %%
#f.
cat("\n\n","Percentage column Added and score deleted:  ","\n")
df['%age']<-df['Score']*5
df[,'Score']<-NULL
print(df)

#g.
cat("\n\n","Details of Qualified students with Age < 19:  ","\n")
df[which(df[,'Age']<19 & df[,'Qualify']=='yes'),]
#subset(df, Age<19 & Qualify=="yes")

#h.
cat("\n\n","Order dataframe by percenytage:  ","\n")
print(df[order(df[,'%age']),])

#i
cat("dimensions",dim(df))
# Out:
#  Percentage column Added and score deleted:
#         Name Attempts Qualify Age  %age
# 1   Antansia        3     yes  18  62.5
# 2       Dima        3      no  17  45.0
# 3  Katherine        2     yes  18  82.5
# 4      James        2      no  18  10.0
# 5      Emily        2      no  19  32.5
# 6    Michael        2     yes  17 100.0
# 7    Matthew        1     yes  18  67.5
# 8      Laura        1      no  17  57.5
# 9      Kevin        2      no  19  40.0
# 10     Jonas        2     yes  19  45.0
#
#
#  Details of Qualified students with Age < 19:
#   Name      Attempts Qualify Age %age
# 1 Antansia  3        yes     18   62.5
# 3 Katherine 2        yes     18   82.5
# 6 Michael   2        yes     17  100.0
# 7 Matthew   1        yes     18   67.5
#  Order dataframe by percenytage:
#         Name Attempts Qualify Age  %age
# 4      James        2      no  18  10.0
# 5      Emily        2      no  19  32.5
# 9      Kevin        2      no  19  40.0
# 2       Dima        3      no  17  45.0
# 10     Jonas        2     yes  19  45.0
# 8      Laura        1      no  17  57.5
# 1   Antansia        3     yes  18  62.5
# 7    Matthew        1     yes  18  67.5
# 3  Katherine        2     yes  18  82.5
# 6    Michael        2     yes  17 100.0
# dimensions 10 5

# %%
#Ques 8 :

data(iris)
summary(iris)
# Out:
#   Sepal.Length    Sepal.Width     Petal.Length    Petal.Width
#  Min.   :4.300   Min.   :2.000   Min.   :1.000   Min.   :0.100
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.300
#  Median :5.800   Median :3.000   Median :4.350   Median :1.300
#  Mean   :5.843   Mean   :3.057   Mean   :3.758   Mean   :1.199
#  3rd Qu.:6.400   3rd Qu.:3.300   3rd Qu.:5.100   3rd Qu.:1.800
#  Max.   :7.900   Max.   :4.400   Max.   :6.900   Max.   :2.500
#        Species
#  setosa    :50
#  versicolor:50
#  virginica :50

# %%
tail(iris,10)
iris[5,]
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 141 6.7          3.1         5.6          2.4         virginica
# 142 6.9          3.1         5.1          2.3         virginica
# 143 5.8          2.7         5.1          1.9         virginica
# 144 6.8          3.2         5.9          2.3         virginica
# 145 6.7          3.3         5.7          2.5         virginica
# 146 6.7          3.0         5.2          2.3         virginica
# 147 6.3          2.5         5.0          1.9         virginica
# 148 6.5          3.0         5.2          2.0         virginica
# 149 6.2          3.4         5.4          2.3         virginica
# 150 5.9          3.0         5.1          1.8         virginica
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 5 5            3.6         1.4          0.2         setosa

# %%
iris[,c(2,3)]
# Out:
#     Sepal.Width Petal.Length
# 1   3.5         1.4
# 2   3.0         1.4
# 3   3.2         1.3
# 4   3.1         1.5
# 5   3.6         1.4
# 6   3.9         1.7
# 7   3.4         1.4
# 8   3.4         1.5
# 9   2.9         1.4
# 10  3.1         1.5
# 11  3.7         1.5
# 12  3.4         1.6
# 13  3.0         1.4
# 14  3.0         1.1
# 15  4.0         1.2
# 16  4.4         1.5
# 17  3.9         1.3
# 18  3.5         1.4
# 19  3.8         1.7
# 20  3.8         1.5
# 21  3.4         1.7
# 22  3.7         1.5
# 23  3.6         1.0
# 24  3.3         1.7
# 25  3.4         1.9
# 26  3.0         1.6
# 27  3.4         1.6
# 28  3.5         1.5
# 29  3.4         1.4
# 30  3.2         1.6
# ... ...         ...
# 121 3.2         5.7
# 122 2.8         4.9
# 123 2.8         6.7
# 124 2.7         4.9
# 125 3.3         5.7
# 126 3.2         6.0
# 127 2.8         4.8
# 128 3.0         4.9
# 129 2.8         5.6
# 130 3.0         5.8
# 131 2.8         6.1
# 132 3.8         6.4
# 133 2.8         5.6
# 134 2.8         5.1
# 135 2.6         5.6
# 136 3.0         6.1
# 137 3.4         5.6
# 138 3.1         5.5
# 139 3.0         4.8
# 140 3.1         5.4
# 141 3.1         5.6
# 142 3.1         5.1
# 143 2.7         5.1
# 144 3.2         5.9
# 145 3.3         5.7
# 146 3.0         5.2
# 147 2.5         5.0
# 148 3.0         5.2
# 149 3.4         5.4
# 150 3.0         5.1

# %%
newiris<-subset(iris,Species=="versicolor")
newiris
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 51  7.0          3.2         4.7          1.4         versicolor
# 52  6.4          3.2         4.5          1.5         versicolor
# 53  6.9          3.1         4.9          1.5         versicolor
# 54  5.5          2.3         4.0          1.3         versicolor
# 55  6.5          2.8         4.6          1.5         versicolor
# 56  5.7          2.8         4.5          1.3         versicolor
# 57  6.3          3.3         4.7          1.6         versicolor
# 58  4.9          2.4         3.3          1.0         versicolor
# 59  6.6          2.9         4.6          1.3         versicolor
# 60  5.2          2.7         3.9          1.4         versicolor
# 61  5.0          2.0         3.5          1.0         versicolor
# 62  5.9          3.0         4.2          1.5         versicolor
# 63  6.0          2.2         4.0          1.0         versicolor
# 64  6.1          2.9         4.7          1.4         versicolor
# 65  5.6          2.9         3.6          1.3         versicolor
# 66  6.7          3.1         4.4          1.4         versicolor
# 67  5.6          3.0         4.5          1.5         versicolor
# 68  5.8          2.7         4.1          1.0         versicolor
# 69  6.2          2.2         4.5          1.5         versicolor
# 70  5.6          2.5         3.9          1.1         versicolor
# 71  5.9          3.2         4.8          1.8         versicolor
# 72  6.1          2.8         4.0          1.3         versicolor
# 73  6.3          2.5         4.9          1.5         versicolor
# 74  6.1          2.8         4.7          1.2         versicolor
# 75  6.4          2.9         4.3          1.3         versicolor
# 76  6.6          3.0         4.4          1.4         versicolor
# 77  6.8          2.8         4.8          1.4         versicolor
# 78  6.7          3.0         5.0          1.7         versicolor
# 79  6.0          2.9         4.5          1.5         versicolor
# 80  5.7          2.6         3.5          1.0         versicolor
# 81  5.5          2.4         3.8          1.1         versicolor
# 82  5.5          2.4         3.7          1.0         versicolor
# 83  5.8          2.7         3.9          1.2         versicolor
# 84  6.0          2.7         5.1          1.6         versicolor
# 85  5.4          3.0         4.5          1.5         versicolor
# 86  6.0          3.4         4.5          1.6         versicolor
# 87  6.7          3.1         4.7          1.5         versicolor
# 88  6.3          2.3         4.4          1.3         versicolor
# 89  5.6          3.0         4.1          1.3         versicolor
# 90  5.5          2.5         4.0          1.3         versicolor
# 91  5.5          2.6         4.4          1.2         versicolor
# 92  6.1          3.0         4.6          1.4         versicolor
# 93  5.8          2.6         4.0          1.2         versicolor
# 94  5.0          2.3         3.3          1.0         versicolor
# 95  5.6          2.7         4.2          1.3         versicolor
# 96  5.7          3.0         4.2          1.2         versicolor
# 97  5.7          2.9         4.2          1.3         versicolor
# 98  6.2          2.9         4.3          1.3         versicolor
# 99  5.1          2.5         3.0          1.1         versicolor
# 100 5.7          2.8         4.1          1.3         versicolor

# %%
plot(iris)
# Out:
# plot without title
