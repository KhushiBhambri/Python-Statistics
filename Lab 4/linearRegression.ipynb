# %% [markdown]
# # LINEAR REGRESSION FROM SCRATCH

# %%
import pandas as pd;
df=pd.read_csv("GoldSilver.csv")

# %%
df.head()
df=df[['gold','silver']]
df
# Out:
#         gold   silver
# 0     100.00   223.42
# 1     100.00   223.42
# 2     100.00   229.84
# 3     100.00   224.58
# 4     100.00   227.99
# ...      ...      ...
# 9127  906.96  1088.32
# 9128  907.61  1093.34
# 9129  909.26  1100.81
# 9130  905.00  1091.16
# 9131  915.88  1100.34
#
# [9132 rows x 2 columns]

# %%
import seaborn as sns;

# %%
sns.heatmap(df.isna())
#to see if there is  any null value
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### we find there is no NA value

# %%
x=df['gold']
y=df['silver']

# %%
 from  sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=101);

# %%
from sklearn.linear_model import LinearRegression

# %%
def cost_function(x,y,a0,a1):
    sum=0;
    for i in range(0,len(x)):
        sum+=(a0+a1*x.loc[i]-y.loc[i])
        sum=sum*sum
    return sum/len(x)

# %%
def gradient_descent(x,y,alpha):
    a0=2;
    a1=(y.loc[0]-a0)/x.loc[0]
    t1=0
    t2=0
    for i in range(0,len(x)):
        t1=(a0+a1*x.loc[i]-y.loc[i]) 
        t2=(a0+a1*x.loc[i]-y.loc[i])*x.loc[i] 
    while t1!=0 and t2!=0:
        a0=a0-alpha*t1/len(x)
        a1=a1-alpha*t2/len(x)
        print(a0,a1)
        if a0==np.nan:
            break
        for i in range(0,len(x)):
            t1=(a0+a1*x.loc[i]-y.loc[i]) 
            t2=(a0+a1*x.loc[i]-y.loc[i])*x.loc[i] 
    return a0,a1

# %%
def predict(x,a0,a1):
    y=a1*x+ a0;
    return y;

# %%
x_train.reset_index(drop=True,inplace=True)
x_test.reset_index(drop=True,inplace=True)
y_train.reset_index(drop=True,inplace=True)
y_test.reset_index(drop=True,inplace=True)

# %%
gradient_descent(x_train.head(10),y_train.head(10),0.002);
# Out:
# -8.831126558953121 -2389.3651484705547
# 105515.19221283699 23288873.066323005
# -1027979554.3639926 -226895647679.37933
# 10015259087561.154 2210567985806057.2
# -9.757530095815248e+16 -2.153682042748342e+19
# 9.506433407100614e+20 2.0982599816152473e+23
# -9.261798348169778e+24 -2.0442641314080334e+27
# 9.02345863781977e+28 1.9916577905395793e+31
# -8.791252273866894e+32 -1.9404052018879005e+35
# 8.565021423032038e+36 1.8904715284916318e+39
# -8.344612313659619e+40 -1.841822829870951e+43
# 8.129875131197231e+44 1.794426038957853e+47
# -7.92066391636505e+48 -1.748248939620094e+51
# 7.716836465945633e+52 1.70326014476352e+55
# -7.518254236126807e+56 -1.6594290749979088e+59
# 7.32478224833188e+60 1.6167259378518121e+63
# -7.136288997473174e+64 -1.5751217075222786e+67
# 6.952646362566548e+68 1.5345881051456885e+71
# -6.773729519646122e+72 -1.495097579576292e+75
# 6.599416856920011e+76 1.456623288659385e+79
# -6.429589892109434e+80 -1.4191390809863945e+83
# ...

# %%
import numpy as np
